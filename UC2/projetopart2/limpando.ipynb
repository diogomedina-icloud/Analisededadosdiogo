# %%
import polars as pl
import time

# %%
import polars as pl

inicial = (
    pl.scan_parquet(r"C:\Users\diogo.durao\Documents\covid_rj.parquet")
    .with_columns(
        pl.col("paciente_idade").cast(pl.Int64, strict=False),
        pl.col("paciente_dataNascimento").str.to_date("%Y-%m-%d", strict=False),
        pl.col("vacina_dataAplicacao").str.to_date("%Y-%m-%d", strict=False)
    )
)

display(inicial.collect().head())
# Out:
# shape: (5, 32)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ document_ ┆ paciente_ ┆ paciente_ ┆ paciente_ ┆ … ┆ vacina_de ┆ vacina_co ┆ vacina_no ┆ sistema_ │
# │ id        ┆ id        ┆ idade     ┆ dataNasci ┆   ┆ scricao_d ┆ digo      ┆ me        ┆ origem   │
# │ ---       ┆ ---       ┆ ---       ┆ mento     ┆   ┆ ose       ┆ ---       ┆ ---       ┆ ---      │
# │ str       ┆ str       ┆ i64       ┆ ---       ┆   ┆ ---       ┆ str       ┆ str       ┆ str      │
# │           ┆           ┆           ┆ date      ┆   ┆ str       ┆           ┆           ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 436b4b52- ┆ 333ec2c1d ┆ 60        ┆ 1963-12-1 ┆ … ┆ Única     ┆ 33        ┆ INF3      ┆ Novo PNI │
# │ 1e20-41b0 ┆ 748f880e6 ┆           ┆ 4         ┆   ┆           ┆           ┆           ┆          │
# │ -bc2b-0a2 ┆ 1248eece8 ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ e4b…      ┆ c06…      ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ d2a4632a- ┆ 67e6e5bd9 ┆ 70        ┆ 1951-11-0 ┆ … ┆ Reforço   ┆ 87        ┆ COVID-19  ┆ Novo PNI │
# │ 9906-4d9d ┆ 1f070cac6 ┆           ┆ 1         ┆   ┆           ┆           ┆ PFIZER -  ┆          │
# │ -9e37-239 ┆ 62d36f014 ┆           ┆           ┆   ┆           ┆           ┆ COMIRNATY ┆          │
# │ fee…      ┆ 84f…      ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 436be4ab- ┆ ec0c97786 ┆ 41        ┆ 1980-01-0 ┆ … ┆ Reforço   ┆ 88        ┆ COVID-19  ┆ Novo PNI │
# │ 8b6b-4517 ┆ 2379ec1e6 ┆           ┆ 3         ┆   ┆           ┆           ┆ JANSSEN - ┆          │
# │ -984e-e3b ┆ cb1da87ee ┆           ┆           ┆   ┆           ┆           ┆ Ad26.COV2 ┆          │
# │ 3af…      ┆ d27…      ┆           ┆           ┆   ┆           ┆           ┆ .S        ┆          │
# │ d2a529c8- ┆ bd8a7396d ┆ 26        ┆ 1995-04-1 ┆ … ┆ 2ª Dose   ┆ 87        ┆ COVID-19  ┆ Novo PNI │
# │ 9a07-4b70 ┆ cae6088da ┆           ┆ 7         ┆   ┆           ┆           ┆ PFIZER -  ┆          │
# │ -ad71-e9b ┆ 675334005 ┆           ┆           ┆   ┆           ┆           ┆ COMIRNATY ┆          │
# │ 864…      ┆ 798…      ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 436d60f1- ┆ c0bd4a543 ┆ 24        ┆ 1997-09-0 ┆ … ┆ 2ª Dose   ┆ 85        ┆ COVID-19  ┆ Novo PNI │
# │ c035-469c ┆ 181499599 ┆           ┆ 4         ┆   ┆           ┆           ┆ ASTRAZENE ┆          │
# │ -929d-a5a ┆ 04e7ce5da ┆           ┆           ┆   ┆           ┆           ┆ CA/FIOCRU ┆          │
# │ d86…      ┆ 15a…      ┆           ┆           ┆   ┆           ┆           ┆ Z -…      ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
# Filtro Simples: Apenas pacientes do Acre
q_ac = inicial.filter(
    pl.col("paciente_endereco_uf") == "AC"
)

# Filtro Composto: Acre e idade maior que 60
q_ac_idosos = inicial.filter(
    (pl.col("paciente_endereco_uf") == "AC") &
    (pl.col("paciente_idade") > 60)
)

# Filtro com Lista: Apenas AC e AP
q_estados = inicial.filter(
    pl.col("paciente_endereco_uf").is_in(["AC", "AP"])
)

display(q_ac.collect())
display(q_ac_idosos.collect())
display(q_estados.collect())
# Out:
# shape: (866, 32)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ document_ ┆ paciente_ ┆ paciente_ ┆ paciente_ ┆ … ┆ vacina_de ┆ vacina_co ┆ vacina_no ┆ sistema_ │
# │ id        ┆ id        ┆ idade     ┆ dataNasci ┆   ┆ scricao_d ┆ digo      ┆ me        ┆ origem   │
# │ ---       ┆ ---       ┆ ---       ┆ mento     ┆   ┆ ose       ┆ ---       ┆ ---       ┆ ---      │
# │ str       ┆ str       ┆ i64       ┆ ---       ┆   ┆ ---       ┆ str       ┆ str       ┆ str      │
# │           ┆           ┆           ┆ date      ┆   ┆ str       ┆           ┆           ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 75d64d74- ┆ ad995b991 ┆ 5         ┆ 2016-11-0 ┆ … ┆ 2ª Dose   ┆ 99        ┆ COVID-19  ┆ Novo PNI │
# │ 7379-41c9 ┆ f043ddc3a ┆           ┆ 3         ┆   ┆           ┆           ┆ PEDIÁTRIC ┆          │
# │ -8808-ae1 ┆ 749ee94bd ┆           ┆           ┆   ┆           ┆           ┆ A -       ┆          │
# │ 033…      ┆ 9c4…      ┆           ┆           ┆   ┆           ┆           ┆ PFIZER C… ┆          │
# │ a567d7e7- ┆ 03c2a7e7a ┆ 5         ┆ 2017-06-2 ┆ … ┆ 1ª Dose   ┆ 87        ┆ COVID-19  ┆ ESUS APS │
# │ 89f6-45d8 ┆ 83bc07e9b ┆           ┆ 3         ┆   ┆           ┆           ┆ PFIZER -  ┆ -        │
# │ -a97c-3fd ┆ bb81272e2 ┆           ┆           ┆   ┆           ┆           ┆ COMIRNATY ┆ NACIONAL │
# │ aae…      ┆ 4f1…      ┆           ┆           ┆   ┆           ┆           ┆           ┆ (OFFLINE │
# │           ┆           ┆           ┆           ┆   ┆           ┆           �
ª Dose   ┆ 87        ┆ COVID-19  ┆ Novo PNI │
# │ dbe8-4d84 ┆ aba0c50b1 ┆           ┆ 6         ┆   ┆           ┆           ┆ PFIZER -  ┆          │
# │ -86ef-84f ┆ 8cacb421b ┆           ┆           ┆   ┆           ┆           ┆ COMIRNATY ┆          │
# │ 65e…      ┆ 4d7…      ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ 6157b7c6- ┆ 3b82725b8 ┆ 61        ┆ 1960-02-0 ┆ … ┆ Reforço   ┆ 87        ┆ COVID-19  ┆ Novo PNI │
# │ 7de4-4c6d ┆ 84eef5f29 ┆           ┆ 7         ┆   ┆           ┆           ┆ PFIZER -  ┆          │
# │ -9b80-3d7 ┆ 291a4d0d5 ┆           ┆           ┆   ┆           ┆           ┆ COMIRNATY ┆          │
# │ ea9…      ┆ b65…      ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 9be20df4- ┆ 82c0a41bd ┆ 34        ┆ 1988-09-0 ┆ … ┆ Reforço   ┆ 103       ┆ COVID-19  ┆ Novo PNI │
# │ b730-4d8a ┆ 5e18a0366 ┆           ┆ 2         ┆   ┆           ┆           ┆ PFIZER -  ┆          │
# │ -bbc3-679 ┆ 980861ef4 ┆           ┆           ┆   ┆           ┆           ┆ COMIRNATY ┆          │
# │ 8c4…      ┆ c04…      ┆           ┆           ┆   ┆           ┆           ┆ BI…       ┆          │
# │ a639ee3a- ┆ d72086888 ┆ 29        ┆ 1992-01-0 ┆ … ┆ 1ª Dose   ┆ 86        ┆ COVID-19  ┆ Novo PNI │
# │ 0a8c-4c64 ┆ 2e14c455b ┆           ┆ 9         ┆   ┆           ┆           ┆ SINOVAC/B ┆          │
# │ -9fc6-88c ┆ 059e334b5 ┆           ┆           ┆   ┆           ┆           ┆ UTANTAN - ┆          │
# │ 912…      ┆ dc6…      ┆           ┆           ┆   ┆           ┆           ┆ CO…       ┆          │
# │ bca8e8d8- ┆ 437e91031 ┆ 20        ┆ 2001-05-0 ┆ … ┆ 2ª Dose   ┆ 87        ┆ COVID-19  ┆ Novo PNI │
# │ 0a9d-4885 ┆ 3e5982a92 ┆           ┆ 3         ┆   ┆           ┆           ┆ PFIZER -  ┆          │
# │ -9123-8cb ┆ 6ac58033a ┆           ┆           ┆   ┆           ┆           ┆ COMIRNATY ┆          │
# │ 3d3…      ┆ 442…      ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 06437f07- ┆ 3a8e8b119 ┆ 7         ┆ 2014-06-1 ┆ … ┆ 1ª Dose   ┆ 99        ┆ COVID-19  ┆ Novo PNI │
# │ 337e-45f6 ┆ c2081c14a ┆           ┆ 2         ┆   ┆           ┆           ┆ PEDIÁTRIC ┆          │
# │ -a74f-74e ┆ 527aabfc9 ┆           ┆           ┆   ┆           ┆           ┆ A -       ┆          │
# │ 7ed…      ┆ 62d…      ┆           ┆           ┆   ┆           ┆           ┆ PFIZER C… ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
# Selecionar apenas colunas importantes
q_simples = inicial.select([
    "paciente_endereco_uf",
    "paciente_endereco_nmMunicipio",
    "paciente_idade",
    "vacina_nome",
    "vacina_dataAplicacao"
])

# Remover colunas menos úteis/pesadas
q_sem_codigos = inicial.drop([
    "document_id",
    "paciente_id"
])

# Seleciona tudo EXCETO as colunas listadas
q_sem_codigos = inicial.select(
    pl.exclude([
        "document_id",
        "paciente_id"
    ])
)

display(q_simples.collect())
display(q_sem_codigos.collect())
# Out:
# shape: (9_764_498, 5)
# ┌────────────────────┬────────────────────┬────────────────┬───────────────────┬───────────────────┐
# │ paciente_endereco_ ┆ paciente_endereco_ ┆ paciente_idade ┆ vacina_nome       ┆ vacina_dataAplica │
# │ uf                 ┆ nmMunicipio        ┆ ---            ┆ ---               ┆ cao               │
# │ ---                ┆ ---                ┆ i64            ┆ str               ┆ ---               │
# │ str                ┆ str                ┆                ┆                   ┆ date              │
# ╞════════════════════╪════════════════════╪════════════════╪═══════════════════╪═══════════════════╡
# │ RJ                 ┆ SAO GONCALO        ┆ 60             ┆ INF3              ┆ 2024-06-20        │
# │ RJ                 ┆ CAMPOS DOS         ┆ 70             ┆ COVID-19 PFIZER - ┆ 2021-11-11        │
# │                    ┆ GOYTACAZES         ┆                ┆ COMIRNATY         ┆                   │
# │ RJ                 ┆ RIO DE JANEIRO     ┆ 41             ┆ COVID-19 JANSSEN  ┆ 2021-12-13        │
# │                    ┆                    ┆                ┆ - Ad26.COV2.S     ┆                   │
# │ RJ                 ┆ BELFORD ROXO       ┆ 26             ┆ COVID-19 PFIZER - ┆ 2021-10-21        │
# │                    ┆                    ┆                ┆ COMIRNATY         ┆                   │
# │ RJ                 ┆ CAMPOS DOS         ┆ 24             ┆ COVID-19 ASTRAZEN ┆ 2021-09-28        │
# │                    ┆ GOYTACAZES         ┆                ┆ ECA/FIOCRUZ -…    ┆                   │
# │ …                  ┆ …                  ┆ …              ┆ …                 ┆ …                 │
# │ RJ                 ┆ RIO DE JANEIRO     ┆ 74             ┆ COVID-19 MODERNA  ┆ 2024-07-03        │
# │                    ┆                    ┆                ┆ - SPIKEVAX        ┆                   │
# │ RJ                 ┆ ITATIAIA           ┆ 34             ┆ COVID-19          ┆ 2021-03-12        │
# │                    ┆                    ┆                ┆ SINOVAC/BUTANTAN  ┆                   │
# │                    ┆                    ┆                ┆ - CO…             ┆                   │
# │ RJ                 ┆ RIO DE JANEIRO     ┆ 32             ┆ COVID-19 ASTRAZEN ┆ 2021-05-27        │
# │                    ┆                    ┆                ┆ ECA/FIOCRUZ -…    ┆                   │
# │ RJ                 ┆ NOVA FRIBURGO      ┆ 67             ┆ COVID-19 ASTRAZEN ┆ 2021-04-13        │
# │                    ┆                    ┆                ┆ ECA/FIOCRUZ -…    ┆                   │
# │ RJ                 ┆ RIO DE JANEIRO     ┆ 68             ┆ INF3              ┆ 2024-03-25        │
# └────────────────────┴────────────────────┴────────────────┴───────────────────┴───────────────────┘
# shape: (9_764_498, 30)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ paciente_ ┆ paciente_ ┆ paciente_ ┆ paciente_ ┆ … ┆ vacina_de ┆ vacina_co ┆ vacina_no ┆ sistema_ │
# │ idade     ┆ dataNasci ┆ enumSexoB ┆ racaCor_c ┆   ┆ scricao_d ┆ digo      ┆ me        ┆ origem   │
# │ ---       ┆ mento     ┆ iologico  ┆ odigo     ┆   ┆ ose       ┆ ---       ┆ ---       ┆ ---      │
# │ i64       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ str       ┆ str       ┆ str      │
# │           ┆ date      ┆ str       ┆ str       ┆   ┆ str       ┆           ┆           ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 60        ┆ 1963-12-1 ┆ F         ┆ 99        ┆ … ┆ Única     ┆ 33        ┆ INF3      ┆ Novo PNI │
# │           ┆ 4         ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 70        ┆ 1951-11-0 ┆ F         ┆ 02        ┆ … ┆ Reforço   ┆ 87        ┆ COVID-19  ┆ Novo PNI │
# │           ┆ 1         ┆           ┆           ┆   ┆           ┆           ┆ PFIZER -  ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ COMIRNATY ┆          │
# │ 41        ┆ 1980-01-0 ┆ M         ┆ 99        ┆ … ┆ Reforço   ┆ 88        ┆ COVID-19  ┆ Novo PNI │
# │           ┆ 3         ┆           ┆           ┆   ┆           ┆           ┆ JANSSEN - ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ Ad26.COV2 ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ .S        ┆          │
# │ 26        ┆ 1995-04-1 ┆ M         ┆ 03        ┆ … ┆ 2ª Dose   ┆ 87        ┆ COVID-19  ┆ Novo PNI │
# │           ┆ 7         ┆           ┆           ┆   ┆           ┆           ┆ PFIZER -  ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ COMIRNATY ┆          │
# │ 24        ┆ 1997-09-0 ┆ F         ┆ 04        ┆ … ┆ 2ª Dose   ┆ 85        ┆ COVID-19  ┆ Novo PNI │
# │           ┆ 4         ┆           ┆           ┆   ┆           ┆           ┆ ASTRAZENE ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ CA/FIOCRU ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ Z -…      ┆          │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ 74        ┆ 1949-11-0 ┆ F         ┆ 03        ┆ … ┆ Dose      ┆ 97        ┆ COVID-19  ┆ Novo PNI │
# │           ┆ 9         ┆           ┆           ┆   ┆           ┆           ┆ MODERNA - ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ SPIKEVAX  ┆          │
# │ 34        ┆ 1986-06-0 ┆ F         ┆ 99        ┆ … ┆ 1ª Dose   ┆ 86        ┆ COVID-19  ┆ Novo PNI │
# │           ┆ 5         ┆           ┆           ┆   ┆           ┆           ┆ SINOVAC/B ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ UTANTAN - ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ CO…       ┆          │
# │ 32        ┆ 1988-12-1 ┆ M         ┆ 01        ┆ … ┆ 1ª Dose   ┆ 85        ┆ COVID-19  ┆ Novo PNI │
# │           ┆ 5         ┆           ┆           ┆   ┆           ┆           ┆ ASTRAZENE ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ CA/FIOCRU ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ Z -…      ┆          │
# │ 67        ┆ 1953-07-1 ┆ F         ┆ 01        ┆ … ┆ 1ª Dose   ┆ 85        ┆ COVID-19  ┆ Novo PNI │
# │           ┆ 8         ┆           ┆           ┆   ┆           ┆           ┆ ASTRAZENE ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ CA/FIOCRU ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ Z -…      ┆          │
# │ 68        ┆ 1956-02-1 ┆ F         ┆ 03        ┆ … ┆ Única     ┆ 33        ┆ INF3      ┆ Novo PNI │
# │           ┆ 0         ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
# Categorizar faixa etária
q_categoria = inicial.with_columns(
    pl.when(pl.col("paciente_idade") >= 60)
    .then(pl.lit("Idoso"))
    .when(pl.col("paciente_idade") >= 18)
    .then(pl.lit("Adulto"))
    .otherwise(pl.lit("Menor de Idade"))
    .alias("FAIXA_ETARIA")
)

display(
    q_categoria.select([
        "paciente_idade",
        "FAIXA_ETARIA"
    ]).collect()
)
# Out:
# shape: (9_764_498, 2)
# ┌────────────────┬──────────────┐
# │ paciente_idade ┆ FAIXA_ETARIA │
# │ ---            ┆ ---          │
# │ i64            ┆ str          │
# ╞════════════════╪══════════════╡
# │ 60             ┆ Idoso        │
# │ 70             ┆ Idoso        │
# │ 41             ┆ Adulto       │
# │ 26             ┆ Adulto       │
# │ 24             ┆ Adulto       │
# │ …              ┆ …            │
# │ 74             ┆ Idoso        │
# │ 34             ┆ Adulto       │
# │ 32             ┆ Adulto       │
# │ 67             ┆ Idoso        │
# │ 68             ┆ Idoso        │
# └────────────────┴──────────────┘

# %%
# Análise por faixa etária
q_analise_categoria = (
    q_categoria
    .group_by("FAIXA_ETARIA")
    .agg([
        pl.len().alias("total_pessoas"),
        pl.col("paciente_idade").mean().alias("media_idade"),
        pl.col("paciente_idade").min().alias("menor_idade"),
        pl.col("paciente_idade").max().alias("maior_idade")
    ])
    .sort("media_idade", descending=True)
)

display(q_analise_categoria.collect())
# Out:
# shape: (3, 5)
# ┌────────────────┬───────────────┬─────────────┬─────────────┬─────────────┐
# │ FAIXA_ETARIA   ┆ total_pessoas ┆ media_idade ┆ menor_idade ┆ maior_idade │
# │ ---            ┆ ---           ┆ ---         ┆ ---         ┆ ---         │
# │ str            ┆ u32           ┆ f64         ┆ i64         ┆ i64         │
# ╞════════════════╪═══════════════╪═════════════╪═════════════╪═════════════╡
# │ Idoso          ┆ 2590486       ┆ 70.378487   ┆ 60          ┆ 128         │
# │ Adulto         ┆ 5964833       ┆ 39.000719   ┆ 18          ┆ 59          │
# │ Menor de Idade ┆ 1209179       ┆ 10.335229   ┆ 0           ┆ 17          │
# └────────────────┴───────────────┴─────────────┴─────────────┴─────────────┘

# %%
# Pegar as primeiras 10 linhas
q_head = inicial.head(10)

# Pegar da linha 100 até a 150
q_meio = inicial.slice(100, 50)

display(q_head.collect())
display(q_meio.collect())
# Out:
# shape: (10, 32)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ document_ ┆ paciente_ ┆ paciente_ ┆ paciente_ ┆ … ┆ vacina_de ┆ vacina_co ┆ vacina_no ┆ sistema_ │
# │ id        ┆ id        ┆ idade     ┆ dataNasci ┆   ┆ scricao_d ┆ digo      ┆ me        ┆ origem   │
# │ ---       ┆ ---       ┆ ---       ┆ mento     ┆   ┆ ose       ┆ ---       ┆ ---       ┆ ---      │
# │ str       ┆ str       ┆ i64       ┆ ---       ┆   ┆ ---       ┆ str       ┆ str       ┆ str      │
# │           ┆           ┆           ┆ date      ┆   ┆ str       ┆           ┆           ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 436b4b52- ┆ 333ec2c1d ┆ 60        ┆ 1963-12-1 ┆ … ┆ Única     ┆ 33        ┆ INF3      ┆ Novo PNI │
# │ 1e20-41b0 ┆ 748f880e6 ┆           ┆ 4         ┆   ┆           ┆           ┆           ┆          │
# │ -bc2b-0a2 ┆ 1248eece8 ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ e4b…      ┆ c06…      ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ d2a4632a- ┆ 67e6e5bd9 ┆ 70        ┆ 1951-11-0 ┆ … ┆ Reforço   ┆ 87        ┆ COVID-19  ┆ Novo PNI │
# │ 9906-4d9d ┆ 1f070cac6 ┆           ┆ 1         ┆   ┆           ┆           ┆ PFIZER -  ┆          │
# │ -9e37-239 ┆ 62d36f014 ┆           ┆           ┆   ┆           ┆           ┆ COMIRNATY ┆          │
# │ fee…      ┆ 84f…      ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 436be4ab- ┆ ec0c97786 ┆ 41        ┆ 1980-01-0 ┆ … ┆ Reforço   ┆ 88        ┆ COVID-19  ┆ Novo PNI │
# │ 8b6b-4517 ┆ 2379ec1e6 ┆           ┆ 3         ┆   ┆           ┆           ┆ JANSSEN - ┆          │
# │ -984e-e3b ┆ cb1da87ee ┆           ┆           ┆   ┆           ┆           ┆ Ad26.COV2 ┆          │
#

# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
# Recorte de linhas específicas
q_recorte_indices = (
    inicial
    .with_row_index("id_linha")
    .filter(pl.col("id_linha").is_in([0, 10, 50]))
    .select([
        "paciente_endereco_uf",
        "paciente_endereco_nmMunicipio"
    ])
)

display(q_recorte_indices.collect())
# Out:
# shape: (3, 2)
# ┌──────────────────────┬───────────────────────────────┐
# │ paciente_endereco_uf ┆ paciente_endereco_nmMunicipio │
# │ ---                  ┆ ---                           │
# │ str                  ┆ str                           │
# ╞══════════════════════╪═══════════════════════════════╡
# │ RJ                   ┆ SAO GONCALO                   │
# │ RJ                   ┆ NOVA FRIBURGO                 │
# │ RJ                   ┆ PETROPOLIS                    │
# └──────────────────────┴───────────────────────────────┘

# %%
q_stats_mun = (
    inicial.group_by("paciente_endereco_nmMunicipio")
    .agg([
        pl.len().alias("total_vacinados"),
        pl.col("paciente_idade").mean().alias("media_idade"),
        pl.col("paciente_idade").max().alias("maior_idade"),
        pl.col("paciente_endereco_uf").first().alias("uf_origem")
    ])
    .sort("total_vacinados", descending=True)
)

display(q_stats_mun.collect())
# Out:
# shape: (4_722, 5)
# ┌───────────────────────────────┬─────────────────┬─────────────┬─────────────┬───────────┐
# │ paciente_endereco_nmMunicipio ┆ total_vacinados ┆ media_idade ┆ maior_idade ┆ uf_origem │
# │ ---                           ┆ ---             ┆ ---         ┆ ---         ┆ ---       │
# │ str                           ┆ u32             ┆ f64         ┆ i64         ┆ str       │
# ╞═══════════════════════════════╪═════════════════╪═════════════╪═════════════╪═══════════╡
# │ RIO DE JANEIRO                ┆ 4287364         ┆ 44.644223   ┆ 128         ┆ RJ        │
# │ SAO GONCALO                   ┆ 473894          ┆ 44.168593   ┆ 124         ┆ RJ        │
# │ DUQUE DE CAXIAS               ┆ 416043          ┆ 41.541889   ┆ 112         ┆ RJ        │
# │ NOVA IGUACU                   ┆ 354168          ┆ 42.728742   ┆ 121         ┆ RJ        │
# │ NITEROI                       ┆ 295141          ┆ 47.207064   ┆ 124         ┆ RJ        │
# │ …                             ┆ …               ┆ …           ┆ …           ┆ …         │
# │ GALIA                         ┆ 1               ┆ 23.0        ┆ 23          ┆ SP        │
# │ FONTE BOA                     ┆ 1               ┆ 32.0        ┆ 32          ┆ AM        │
# │ CORDILHEIRA ALTA              ┆ 1               ┆ 33.0        ┆ 33          ┆ SC        │
# │ LOBATO                        ┆ 1               ┆ 30.0        ┆ 30          ┆ PR        │
# │ Centro                        ┆ 1               ┆ 35.0        ┆ 35          ┆           │
# └───────────────────────────────┴─────────────────┴─────────────┴─────────────┴───────────┘

# %%
import polars as pl
import time

print("=== TESTE 1: Processamento SEM StringCache ===")
start_1 = time.time()

q_sem_cache = (
    pl.scan_parquet(r"C:\Users\diogo.durao\Documents\covid_rj.parquet")
    .with_columns(
        pl.col("paciente_idade").cast(pl.Int64, strict=False),
        pl.col("paciente_dataNascimento").str.to_date("%Y-%m-%d", strict=False),
        pl.col("vacina_dataAplicacao").str.to_date("%Y-%m-%d", strict=False)
    )
    .group_by(["paciente_endereco_uf", "paciente_endereco_nmMunicipio"])
    .agg([
        pl.col("paciente_idade").mean().alias("media_idade"),
        pl.col("paciente_idade").std().alias("desvio_idade")
    ])
    .sort("media_idade", descending=True)
)

df_1 = q_sem_cache.collect()
end_1 = time.time()
tempo_sem = end_1 - start_1

print(f"Tempo SEM Cache: {tempo_sem:.4f} segundos")
print(f"Uso de memória estimado (coluna UF): {df_1['paciente_endereco_uf'].estimated_size()} bytes\n")

display(df_1)
# Out:
# === TESTE 1: Processamento SEM StringCache ===
# Tempo SEM Cache: 0.9569 segundos
# Uso de memória estimado (coluna UF): 9892 bytes
# shape: (4_955, 4)
# ┌──────────────────────┬───────────────────────────────┬─────────────┬──────────────┐
# │ paciente_endereco_uf ┆ paciente_endereco_nmMunicipio ┆ media_idade ┆ desvio_idade │
# │ ---                  ┆ ---                           ┆ ---         ┆ ---          │
# │ str                  ┆ str                           ┆ f64         ┆ f64          │
# ╞══════════════════════╪═══════════════════════════════╪═════════════╪══════════════╡
# │ MT                   ┆ ALTO PARAGUAI                 ┆ 92.5        ┆ 2.12132      │
# │ TO                   ┆ CASEARA                       ┆ 92.0        ┆ null         │
# │ MS                   ┆ CORGUINHO                     ┆ 91.333333   ┆ 0.57735      │
# │ GO                   ┆ CAVALCANTE                    ┆ 90.0        ┆ 19.79899     │
# │ PR                   ┆ KALORE                        ┆ 89.0        ┆ null         │
# │ …                    ┆ …                             ┆ …           ┆ …            │
# │ BA                   ┆ IUIU                          ┆ 4.0         ┆ null         │
# │ GO                   ┆ ARENOPOLIS                    ┆ 4.0         ┆ null         │
# │ RS                   ┆ GRAMADO DOS LOUREIROS         ┆ 3.0         ┆ null         │
# │ MG                   ┆ CONCEICAO DAS PEDRAS          ┆ 2.0         ┆ null         │
# │ PR                   ┆ JARDIM ALEGRE                 ┆ 2.0         ┆ null         │
# └──────────────────────┴───────────────────────────────┴─────────────┴──────────────┘

# %%
print("=== TESTE 2: Processamento COM StringCache ===")

with pl.StringCache():
    start_2 = time.time()

    q_com_cache = (
        pl.scan_parquet(r"C:\Users\diogo.durao\Documents\covid_rj.parquet")
        .with_columns(
            pl.col("paciente_idade").cast(pl.Int64, strict=False),
            pl.col("paciente_dataNascimento").str.to_date("%Y-%m-%d", strict=False),
            pl.col("vacina_dataAplicacao").str.to_date("%Y-%m-%d", strict=False)
        )
        .group_by([
            "paciente_endereco_uf",
            "paciente_endereco_nmMunicipio"
        ])
        .agg([
            pl.col("paciente_idade").mean().alias("media_idade"),
            pl.col("paciente_idade").std().alias("desvio_idade")
        ])
        .sort("media_idade", descending=True)
    )

    df_2 = q_com_cache.collect()
    end_2 = time.time()

tempo_com = end_2 - start_2

print(f"Tempo COM Cache: {tempo_com:.4f} segundos")
print(f"Uso de memória estimado (coluna UF): {df_2['paciente_endereco_uf'].estimated_size()} bytes\n")
# Out:
# === TESTE 2: Processamento COM StringCache ===
# Tempo COM Cache: 0.9011 segundos
# Uso de memória estimado (coluna UF): 9892 bytes
