# %%
import pandas as pd
import polars as pl
import pyarrow as pa
import pyarrow.parquet as pq
import os

# %%
import polars as pl

arquivo1=pl.read_csv(r"C:\Users\Usuario\OneDrive\Documentos\Covid_AC.csv", separator=";", encoding="utf-8", infer_schema_length=0)
arquivo2=pl.read_csv(r"C:\Users\Usuario\OneDrive\Documentos\Covid_AP.csv", separator=";", encoding="utf-8", infer_schema_length=0)

df_polars=pl.concat([arquivo1,arquivo2])

display(df_polars.head())
# Out:
# shape: (5, 32)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ document_ ┆ paciente_ ┆ paciente_ ┆ paciente_ ┆ … ┆ vacina_de ┆ vacina_co ┆ vacina_no ┆ sistema_ │
# │ id        ┆ id        ┆ idade     ┆ dataNasci ┆   ┆ scricao_d ┆ digo      ┆ me        ┆ origem   │
# │ ---       ┆ ---       ┆ ---       ┆ mento     ┆   ┆ ose       ┆ ---       ┆ ---       ┆ ---      │
# │ str       ┆ str       ┆ str       ┆ ---       ┆   ┆ ---       ┆ str       ┆ str       ┆ str      │
# │           ┆           ┆           ┆ str       ┆   ┆ str       ┆           ┆           ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ db312f60- ┆ 29e606de7 ┆ 30        ┆ 1992-06-2 ┆ … ┆ 1ª Dose   ┆ 87        ┆ COVID-19  ┆ Novo PNI │
# │ 0972-48a6 ┆ 35a451882 ┆           ┆ 9         ┆   ┆           ┆           ┆ PFIZER -  ┆          │
# ...

# %%
import polars as pl

arquivo_csv = r"C:\Users\Usuario\OneDrive\Documentos\Covid_AC.csv"
arquivo_parquet = r"C:\Users\Usuario\OneDrive\Documentos\Covid_AC.parquet"

lazy_query = pl.scan_csv(
    arquivo_csv,
    separator=';',
    encoding='utf8-lossy'
)

lazy_query.sink_parquet(arquivo_parquet)

print(f"Arquivo '{arquivo_csv}' convertido para '{arquivo_parquet}' com sucesso!")
# Out:
# Arquivo 'C:\Users\Usuario\OneDrive\Documentos\Covid_AC.csv' convertido para 'C:\Users\Usuario\OneDrive\Documentos\Covid_AC.parquet' com sucesso!

# %%
import polars as pl

arquivo_csv = r"C:\Users\Usuario\OneDrive\Documentos\Covid_AP.csv"
arquivo_parquet = r"C:\Users\Usuario\OneDrive\Documentos\Covid_AP.parquet"

lazy_query = pl.scan_csv(arquivo_csv, separator=";", encoding="utf8-lossy", infer_schema_length=0)

lazy_query.sink_parquet(arquivo_parquet)

print(f"Arquivo '{arquivo_csv}' convertido para '{arquivo_parquet}' com sucesso!")
# Out:
# Arquivo 'C:\Users\Usuario\OneDrive\Documentos\Covid_AP.csv' convertido para 'C:\Users\Usuario\OneDrive\Documentos\Covid_AP.parquet' com sucesso!
